# %%
import csv
import pandas as pd
import os

# %%
def limpiar(path):
    data = pd.read_csv(path, header= None, sep = '\n' )
    data = data[0].str.split(',', expand=True)
    index=int(data[data[0]=="Record"].index[0])
    data.drop(range(0,index),axis=0,inplace=True)
    data.reset_index(drop=True,inplace=True)
    data.columns=data.iloc[0]
    data.drop(0,axis=0,inplace=True)
    data.dropna(axis = 1, how ='all',inplace=True)
    return data.copy()

# %%
LPDS_Dir = "./"
filename = "LDP Export 2020-may.-22_01-00-24_Recorder2.csv"
path = os.path.join(LPDS_Dir,filename)

LPDS= limpiar(path)
LPDS.head(1000)
# Out:
# 0   Record         Date       Time  Status       "PFT3"       "PFTA"  "PFTB"  \
# 1      249   04/01/2020   00:05:00   "..."    0.8794533    0.8794533       1
# 2      248   04/01/2020   00:10:00   "..."   0.88011801   0.88011801       1
# 3      247   04/01/2020   00:15:00   "..."   0.87851262   0.87851262       1
# 4      246   04/01/2020   00:20:00   "..."   0.99947327   0.99947327       1
# 5      245   04/01/2020   00:25:00   "..."            1            1       1
# ..     ...          ...        ...     ...          ...          ...     ...
# 245      5   04/17/2020   10:15:00   "..."            1            1       1
# 246      4   04/17/2020   10:20:00   "..."            1            1       1
# 247      3   04/17/2020   10:25:00   "..."            1            1       1
# 248      2   04/17/2020   10:30:00   "..."            1            1       1
# 249      1   04/17/2020   10:35:00   "(2)"            0            0       0
#
# 0    "PFTC"    "LDPFT3"
# ...

# %%
LPDS_Dir = "./"
filename = "LDP Export 2020-may.-22_01-00-24_Recorder3.csv"
path = os.path.join(LPDS_Dir,filename)

# %%
LPDS2= limpiar(path)
LPDS2.head(1000)
# Out:
# 0    Record         Date       Time  Status     "HRM3_IA"    "HRM5_IA"  \
# 1      1235   04/01/2020   00:01:00   "..."   11.28416348   3.75704026
# 2      1234   04/01/2020   00:02:00   "..."   11.46753693   3.81699681
# 3      1233   04/01/2020   00:03:00   "..."   11.22057343   3.73841763
# 4      1232   04/01/2020   00:04:00   "..."   11.17346478   3.72342849
# 5      1231   04/01/2020   00:05:00   "..."   11.15633392   3.71797776
# ...     ...          ...        ...     ...           ...          ...
# 996     240   04/02/2020   12:38:00   "..."   12.78847313   4.65125847
# 997     239   04/02/2020   12:39:00   "..."   12.86142159   4.50714684
# 998     238   04/02/2020   12:40:00   "..."   12.95110989   4.59747028
# 999     237   04/02/2020   12:41:00   "..."   12.97780228   4.63823795
# 1000    236   04/02/2020   12:42:00   "..."   13.02930355   4.69866514
#
# 0       "HRM7_IA"     "HRM9_IA"   "HRM11_IA"  "HRM13_IA"  "HRM15_IA"  \
# ...

# %%
LPDS_Dir = "./"
filename = "LDP Export 2020-may.-22_01-00-24_Recorder2.csv"
path = os.path.join(LPDS_Dir,filename)

LPDS= limpiar(path)
LPDS.head(1000)

# %%
LPDS_Dir = "./"
filename = "LDP Export 2020-may.-22_01-00-24_Recorder2.csv"
path = os.path.join(LPDS_Dir,filename)

LPDS= limpiar(path)
LPDS.head(1000)

# %%
LPDS_Dir = "./"
filename = "LDP Export 2020-may.-22_01-00-24_Recorder2.csv"
path = os.path.join(LPDS_Dir,filename)

LPDS= limpiar(path)
LPDS.head(1000)
